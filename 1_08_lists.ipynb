# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham11122/Python-practice/blob/main/1_08_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_08_Lists.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Access Second Job Title (1.8.1)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_titles[1]
# Out:
# 'Data Analyst'

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Change Third Job Title (1.8.2)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_titles[2] ='bigquery'

job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'bigquery']

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Slice Job Titles List (1.8.3)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']

# %%
first_two = job_titles[0:2]
first_two
# Out:
# ['Data Scientist', 'Data Analyst']

# %%
last_two = job_titles[2:4]
last_two
# Out:
# ['Machine Learning Engineer', 'Data Engineer']

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Append Job Title (1.8.4)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_titles.append('Data Aanlyst')
job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Aanlyst']

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Insert Job Title (1.8.5)

# %%
# Code Needed
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_titles.insert(2,'Data Annoter')

# %%
job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'Data Annoter', 'Machine Learning Engineer']

# %% [markdown]
# ---
