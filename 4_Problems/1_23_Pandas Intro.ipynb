# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_23_Pandas Intro.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Load and Display Last 5 Rows (1.23.1)

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/data_jobs.csv')

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.tail(5)
# Out:
#              job_title_short             job_title  \
# 358714        Data Scientist        Data Scientist
# 358715      Business Analyst    Production Analyst
# 358716         Data Engineer    Data Engineer, Ads
# 358717   Senior Data Analyst   Senior Data Analyst
# 358718  Senior Data Engineer  Senior Data Engineer
#
#                                job_location          job_via  \
# 358714     Abu Dhabi - United Arab Emirates  via Recruit.net
# 358715                               Mexico     via The Muse
# 358716  Da’an District, Taipei City, Taiwan     via 1111人力銀行
# 358717                       Birmingham, UK  via Recruit.net
# 358718                            Singapore  via Recruit.net
#
#        job_schedule_type  job_work_from_home       search_location  \
# 358714         Full-time               False  United Arab Emirates
# 358715         Full-time               False                Mexico
# 358716               NaN               False                Taiwan
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Select Job Location Column (1.23.2)

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df['job_location']
# Out:
# 0                               Watertown, CT
# 1                Guadalajara, Jalisco, Mexico
# 2                             Berlin, Germany
# 3                             San Antonio, TX
# 4                              Washington, DC
#                          ...
# 358714       Abu Dhabi - United Arab Emirates
# 358715                                 Mexico
# 358716    Da’an District, Taipei City, Taiwan
# 358717                         Birmingham, UK
# 358718                              Singapore
# Name: job_location, Length: 358719, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Select Search Location Column (1.23.3)

# %%
df['search_location']
# Out:
# 0         Texas, United States
# 1                       Mexico
# 2                      Germany
# 3         Texas, United States
# 4                        Sudan
#                   ...
# 358714    United Arab Emirates
# 358715                  Mexico
# 358716                  Taiwan
# 358717          United Kingdom
# 358718               Singapore
# Name: search_location, Length: 358719, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Select Job Title from 57th Row Element (1.23.4)

# %%
df.loc[57, 'job_title']
# Out:
# 'Data Engineer'

# %% [markdown]
# Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358719 entries, 0 to 358718
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        358719 non-null  object
#  1   job_title              358719 non-null  object
#  2   job_location           358352 non-null  object
#  3   job_via                358716 non-null  object
#  4   job_schedule_type      353031 non-null  object
#  5   job_work_from_home     358719 non-null  bool
#  6   search_location        358719 non-null  object
#  7   job_posted_date        358719 non-null  object
#  8   job_no_degree_mention  358719 non-null  bool
#  9   job_health_insurance   358719 non-null  bool
#  10  job_country            358699 non-null  object
#  11  salary_rate            13944 non-null   object
#  12  salary_year_avg        9197 non-null    float64
#  13  salary_hour_avg        4577 non-null    float64
# ...

# %% [markdown]
# # Access Thrid Row

# %%
df.iloc[3:5]
# Out:
#   job_title_short                                          job_title  \
# 3   Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4   Data Engineer                             Data Engineer- Sr Jobs
#
#       job_location             job_via job_schedule_type  job_work_from_home  \
# 3  San Antonio, TX   via Diversity.com         Full-time               False
# 4   Washington, DC  via Clearance Jobs         Full-time               False
#
#         search_location      job_posted_date  job_no_degree_mention  \
# 3  Texas, United States  2023-07-04 13:01:41                   True
# 4                 Sudan  2023-08-07 14:29:36                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 3                 False  United States         NaN              NaN
# 4                 False          Sudan         NaN              NaN
#
#    salary_hour_avg                  company_name  \
# 3              NaN  Southwest Research Institute
# ...

# %% [markdown]
# ---

# %% [markdown]
# # 🟨 Unique Job Countries

# %%
df.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
# ...

# %%
missing_values_count = df.isnull().sum()
missing_values_df = pd.DataFrame(missing_values_count, columns=['missing_count'])
missing_values_df = missing_values_df.sort_values(by='missing_count', ascending=False)
display(missing_values_df[missing_values_df['missing_count'] > 0])
# Out:
#                    missing_count
# salary_hour_avg           354142
# salary_year_avg           349522
# salary_rate               344775
# job_type_skills            56076
# job_skills                 56076
# job_schedule_type           5688
# job_location                 367
# job_country                   20
# company_name                   6
# job_via                        3

# %% [markdown]
# # 🟨 Filter by Job Schedule Type and Display

# %%
df.count()
# Out:
# job_title_short          358719
# job_title                358719
# job_location             358352
# job_via                  358716
# job_schedule_type        353031
# job_work_from_home       358719
# search_location          358719
# job_posted_date          358719
# job_no_degree_mention    358719
# job_health_insurance     358719
# job_country              358699
# salary_rate               13944
# salary_year_avg            9197
# salary_hour_avg            4577
# company_name             358713
# job_skills               302643
# job_type_skills          302643
# dtype: int64
