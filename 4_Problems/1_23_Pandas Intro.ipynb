# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_23_Pandas Intro.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # pandas intro
#
# *   Pandas is a Python library used for working with data sets.
# *   It lets us analyze, clean, explore and manipulate data.

# %%
# !conda install pandas

import pandas as pd

# %%
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %% [markdown]
# ## 🟩 Load and Display Last 5 Rows (1.23.1)

# %%
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
# 2               False               Germany  2023-10-10 13:14:55
# 3               False  Texas, United States  2023-07-04 13:01:41
# 4               False                 Sudan  2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.tail(10)
# Out:
#              job_title_short  \
# 785731         Data Engineer
# 785732         Data Engineer
# 785733     Software Engineer
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785733                                    DevOps Engineer
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                   job_location                     job_via  \
# 785731  Overland Park, Kansas, Amerika Serikat            melalui LinkedIn
# 785732                      Heidelberg, Jerman  melalui Top County Careers
# 785733                               Singapura         melalui Trabajo.org
# 785734                      Almaty, Kazakhstan               melalui Melga
# 785735                          Berlin, Jerman  melalui Top County Careers
# 785736                               Singapura         melalui Trabajo.org
# 785737                      Bad Rodach, Jerman   melalui BeBee Deutschland
# 785738                                Malaysia            melalui Ricebowl
# 785739     Newark, New Jersey, Amerika Serikat         melalui Recruit.net
# 785740                                   India              melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785731   Pekerjaan tetap               False           Sudan
# 785732   Pekerjaan tetap               False         Germany
# 785733   Pekerjaan tetap               False       Singapore
# 785734   Pekerjaan tetap               False      Kazakhstan
# 785735   Pekerjaan tetap               False         Germany
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785731  2023-03-12 06:32:17                  False                 False
# 785732  2023-03-13 06:18:59                  False                 False
# 785733  2023-03-13 06:16:17                  False                 False
# 785734  2023-03-12 06:31:13                  False                 False
# 785735  2023-03-13 06:19:07                  False                 False
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785731       Sudan        None              NaN              NaN
# 785732     Germany        None              NaN              NaN
# 785733   Singapore        None              NaN              NaN
# 785734  Kazakhstan        None              NaN              NaN
# 785735     Germany        None              NaN              NaN
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785731        Shamrock Trading Corporation
# 785732                Heidelberg Materials
# 785733                   Hydra X Pte. Ltd.
# 785734           Staff-UP Consulting Group
# 785735                            Pure App
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785731  ['nosql', 'mongodb', 'mongodb', 'python', 'ela...
# 785732  ['python', 'c#', 'java', 'scala', 'sql', 'post...
# 785733                           ['docker', 'kubernetes']
# 785734                                        ['windows']
# 785735  ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785731  {'analyst_tools': ['excel'], 'cloud': ['aws', ...
# 785732  {'cloud': ['azure', 'databricks'], 'databases'...
# 785733                {'other': ['docker', 'kubernetes']}
# 785734                                {'os': ['windows']}
# 785735  {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df['job_title_short']
# Out:
# 0         Senior Data Engineer
# 1                 Data Analyst
# 2                Data Engineer
# 3                Data Engineer
# 4                Data Engineer
#                   ...
# 785736       Software Engineer
# 785737            Data Analyst
# 785738        Business Analyst
# 785739           Data Engineer
# 785740       Software Engineer
# Name: job_title_short, Length: 785741, dtype: object

# %%
df.job_title_short
# Out:
# 0         Senior Data Engineer
# 1                 Data Analyst
# 2                Data Engineer
# 3                Data Engineer
# 4                Data Engineer
#                   ...
# 785736       Software Engineer
# 785737            Data Analyst
# 785738        Business Analyst
# 785739           Data Engineer
# 785740       Software Engineer
# Name: job_title_short, Length: 785741, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # View all columns

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %% [markdown]
# ## 🟩 Select Job Location Column (1.23.2)

# %%
df[['job_location', 'search_location']] #showing multiple columns
# Out:
#                                job_location       search_location
# 0                             Watertown, CT  Texas, United States
# 1              Guadalajara, Jalisco, Mexico                Mexico
# 2                           Berlin, Germany               Germany
# 3                           San Antonio, TX  Texas, United States
# 4                            Washington, DC                 Sudan
# ...                                     ...                   ...
# 785736                            Singapura             Singapore
# 785737                   Bad Rodach, Jerman               Germany
# 785738                             Malaysia              Malaysia
# 785739  Newark, New Jersey, Amerika Serikat                 Sudan
# 785740                                India                 India
#
# [785741 rows x 2 columns]

# %% [markdown]
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), float64(2), object(12)
# memory usage: 86.2+ MB

# %% [markdown]
# ---

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %% [markdown]
# ## 🟩 Pandas Inspection

# %%
df['job_title_short'].unique() # for unique values
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
len(df) # - Get length of DataFrame
# Out:
# 785741

# %%
df.shape # - Get the (rows, columns)
# Out:
# (785741, 17)

# %%
df.index # - Describe index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.columns # - Describe DataFrame columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills'],
#       dtype='object')

# %%
df.count() # - Number of non-NA values
# Out:
# job_title_short          785741
# job_title                785740
# job_location             784696
# job_via                  785733
# job_schedule_type        773074
# job_work_from_home       785741
# search_location          785741
# job_posted_date          785741
# job_no_degree_mention    785741
# job_health_insurance     785741
# job_country              785692
# salary_rate               33067
# salary_year_avg           22003
# salary_hour_avg           10662
# company_name             785723
# job_skills               668704
# job_type_skills          668704
# dtype: int64

# %%
df[['job_title_short','job_title']].count() # - Number of non-NA values
# Out:
# job_title_short    785741
# job_title          785740
# dtype: int64

# %% [markdown]
# ---

# %%
df.iloc[1] #to locate the row
# Out:
# job_title_short                                               Data Analyst
# job_title                                                     Data Analyst
# job_location                                  Guadalajara, Jalisco, Mexico
# job_via                                                   via BeBee México
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Mexico
# job_posted_date                                        2023-01-14 13:18:07
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                         Mexico
# salary_rate                                                           None
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                    Hewlett Packard Enterprise
# job_skills               ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# job_type_skills          {'analyst_tools': ['power bi', 'tableau'], 'pr...
# Name: 1, dtype: object

# %%
df.iloc[1:10] #to locate multiple row
# Out:
#         job_title_short                                          job_title  \
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# 3               San Antonio, TX   via Diversity.com                 Full-time
# 4                Washington, DC  via Clearance Jobs                 Full-time
# 5                      Anywhere    via ZipRecruiter  Contractor and Temp work
# 6                  Dearborn, MI        via LinkedIn                 Full-time
# 7                      Anywhere        via LinkedIn                 Full-time
# 8           Copenhagen, Denmark     via Trabajo.org                 Full-time
# 9                      Anywhere    via ZipRecruiter                 Full-time
#
#    job_work_from_home          search_location      job_posted_date  \
# 1               False                   Mexico  2023-01-14 13:18:07
# 2               False                  Germany  2023-10-10 13:14:55
# 3               False     Texas, United States  2023-07-04 13:01:41
# 4               False                    Sudan  2023-08-07 14:29:36
# 5                True                  Georgia  2023-11-07 14:01:59
# 6               False   Florida, United States  2023-03-27 13:18:18
# 7                True                  Romania  2023-12-07 13:40:49
# 8               False                  Denmark  2023-06-05 13:44:34
# 9                True  New York, United States  2023-04-23 13:02:57
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
# 5                  False                 False  United States        None
# 6                  False                 False  United States        None
# 7                  False                 False        Romania        None
# 8                  False                 False        Denmark        None
# 9                  False                 False  United States        None
#
#    salary_year_avg  salary_hour_avg                   company_name  \
# 1              NaN              NaN     Hewlett Packard Enterprise
# 2              NaN              NaN       ALPHA Augmented Services
# 3              NaN              NaN   Southwest Research Institute
# 4              NaN              NaN                Kristina Daniel
# 5              NaN              NaN                smart folks inc
# 6              NaN              NaN  Miracle Software Systems, Inc
# 7              NaN              NaN                          Zitec
# 8              NaN              NaN                         Hempel
# 9              NaN              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7  ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                ['excel', 'powerpoint', 'power bi']
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# 6  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 7  {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 8  {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 9  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %% [markdown]
# # Filtering Rows

# %% [markdown]
# Example:
# Let's only return rows that have an salary_year_avg greater than 100000.

# %%
df[df['salary_year_avg'] > 100000]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 116     Data Scientist                                     Data Scientist
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# 116                                    Anywhere     via LinkedIn
# ...                                         ...              ...
# 785624                          Mt Prospect, IL  via Ai-Jobs.net
# 785641                             New York, NY         via Dice
# 785648                        Pleasant Hill, CA  via Ai-Jobs.net
# 785682                      Reutlingen, Germany  via Ai-Jobs.net
# 785692                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# 116            Full-time                True       Texas, United States
# ...                  ...                 ...                        ...
# 785624         Full-time               False    Illinois, United States
# 785641         Full-time               False                    Georgia
# 785648         Full-time               False  California, United States
# 785682         Full-time               False                    Germany
# 785692         Full-time               False    Illinois, United States
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28      2023-08-01 13:37:57                  False                 False
# 77      2023-06-26 14:22:54                  False                 False
# 92      2023-02-21 13:29:59                  False                  True
# 100     2023-07-31 13:01:18                  False                  True
# 116     2023-10-04 13:04:23                  False                 False
# ...                     ...                    ...                   ...
# 785624  2023-08-31 06:02:16                  False                  True
# 785641  2023-01-04 16:36:07                   True                 False
# 785648  2023-04-12 06:02:51                  False                  True
# 785682  2023-03-04 06:16:08                  False                 False
# 785692  2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0              NaN
# 77              Sudan        year         140000.0              NaN
# 92      United States        year         120000.0              NaN
# 100     United States        year         228222.0              NaN
# 116     United States        year         114000.0              NaN
# ...               ...         ...              ...              ...
# 785624  United States        year         139216.0              NaN
# 785641  United States        year         150000.0              NaN
# 785648  United States        year         221875.0              NaN
# 785682        Germany        year         157500.0              NaN
# 785692  United States        year         157500.0              NaN
#
#                  company_name  \
# 28                   Netskope
# 77                 Intelletec
# 92               Apex Systems
# 100                    TikTok
# 116        4 Corner Resources
# ...                       ...
# 785624            Bosch Group
# 785641  Engage Partners, Inc.
# 785648                 84.51°
# 785682            Bosch Group
# 785692                 Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 116     ['r', 'python', 'sql', 't-sql', 'hadoop', 'spa...
# ...                                                   ...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785641                                               None
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 116     {'analyst_tools': ['tableau'], 'libraries': ['...
# ...                                                   ...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641                                               None
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [13945 rows x 17 columns]

# %%
#What if I only wanted to look at rows where the job title (job_title_short) is 'Business Analyst'?
df[df['job_title_short'] == 'Business Analyst']
# Out:
#          job_title_short                                   job_title  \
# 8       Business Analyst    Technology & Operations Business Analyst
# 60      Business Analyst                Business Intelligence Intern
# 66      Business Analyst                                 BI Engineer
# 71      Business Analyst                            Business Analyst
# 138     Business Analyst                          Commercial Analyst
# ...                  ...                                         ...
# 785720  Business Analyst                       Senior Sales Engineer
# 785721  Business Analyst                    IT Business Analyst Data
# 785722  Business Analyst  Business Analytics Training and Internship
# 785734  Business Analyst                           PreSales Engineer
# 785738  Business Analyst              Commercial Analyst - Start Now
#
#                  job_location                job_via job_schedule_type  \
# 8         Copenhagen, Denmark        via Trabajo.org         Full-time
# 60                 Dallas, TX           via LinkedIn         Full-time
# 66                    Namibia     via Intellijobs.ai         Full-time
# 71      Tel Aviv-Yafo, Israel             via Comeet         Full-time
# 138              South Africa           via LinkedIn         Full-time
# ...                       ...                    ...               ...
# 785720          Jenewa, Swiss  melalui BeBee Schweiz   Pekerjaan tetap
# 785721                 Jerman         melalui Indeed   Pekerjaan tetap
# 785722                 Jerman       melalui LinkedIn              None
# 785734     Almaty, Kazakhstan          melalui Melga   Pekerjaan tetap
# 785738               Malaysia       melalui Ricebowl   Pekerjaan tetap
#
#         job_work_from_home       search_location      job_posted_date  \
# 8                    False               Denmark  2023-06-05 13:44:34
# 60                   False  Texas, United States  2023-01-04 13:02:07
# 66                   False               Namibia  2023-03-05 14:10:49
# 71                   False                Israel  2023-09-05 13:50:12
# 138                  False          South Africa  2023-02-14 13:36:23
# ...                    ...                   ...                  ...
# 785720               False           Switzerland  2023-03-12 06:37:25
# 785721               False               Germany  2023-03-12 06:18:18
# 785722               False               Germany  2023-03-12 06:18:18
# 785734               False            Kazakhstan  2023-03-12 06:31:13
# 785738               False              Malaysia  2023-03-12 06:32:36
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 8                       False                 False        Denmark
# 60                      False                 False  United States
# 66                      False                 False        Namibia
# 71                      False                 False         Israel
# 138                      True                 False   South Africa
# ...                       ...                   ...            ...
# 785720                  False                 False    Switzerland
# 785721                  False                 False        Germany
# 785722                  False                 False        Germany
# 785734                  False                 False     Kazakhstan
# 785738                  False                 False       Malaysia
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 8             None              NaN              NaN
# 60            None              NaN              NaN
# 66            None              NaN              NaN
# 71            None              NaN              NaN
# 138           None              NaN              NaN
# ...            ...              ...              ...
# 785720        None              NaN              NaN
# 785721        None              NaN              NaN
# 785722        None              NaN              NaN
# 785734        None              NaN              NaN
# 785738        None              NaN              NaN
#
#                      company_name  \
# 8                          Hempel
# 60                         Copart
# 66                        Innover
# 71                     ironSource
# 138                           PEP
# ...                           ...
# 785720                  Snowflake
# 785721                     Raisin
# 785722                      OESON
# 785734  Staff-UP Consulting Group
# 785738      Lendlease Corporation
#
#                                                job_skills  \
# 8                     ['excel', 'powerpoint', 'power bi']
# 60          ['r', 'python', 'sql', 'tableau', 'power bi']
# 66                    ['sql', 'gcp', 'looker', 'tableau']
# 71                                       ['sql', 'excel']
# 138                     ['sql', 'tableau', 'spss', 'sap']
# ...                                                   ...
# 785720                      ['sql', 'snowflake', 'excel']
# 785721  ['sql', 'python', 'aws', 'looker', 'tableau', ...
# 785722                                         ['python']
# 785734                                        ['windows']
# 785738                            ['powerpoint', 'excel']
#
#                                           job_type_skills
# 8       {'analyst_tools': ['excel', 'powerpoint', 'pow...
# 60      {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 66      {'analyst_tools': ['looker', 'tableau'], 'clou...
# 71      {'analyst_tools': ['excel'], 'programming': ['...
# 138     {'analyst_tools': ['tableau', 'spss', 'sap'], ...
# ...                                                   ...
# 785720  {'analyst_tools': ['excel'], 'cloud': ['snowfl...
# 785721  {'analyst_tools': ['looker', 'tableau', 'splun...
# 785722                        {'programming': ['python']}
# 785734                                {'os': ['windows']}
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
#
# [49063 rows x 17 columns]

# %% [markdown]
# **Finding Not null values**

# %% [markdown]
# Let's only get rows where it has a yearly salary listed. Meaning that salary_year_avg is not null.

# %%
df[df['salary_year_avg'].notna()]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# 109                                    Anywhere       via Get.It
# ...                                         ...              ...
# 785624                          Mt Prospect, IL  via Ai-Jobs.net
# 785641                             New York, NY         via Dice
# 785648                        Pleasant Hill, CA  via Ai-Jobs.net
# 785682                      Reutlingen, Germany  via Ai-Jobs.net
# 785692                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# 109            Full-time                True    Illinois, United States
# ...                  ...                 ...                        ...
# 785624         Full-time               False    Illinois, United States
# 785641         Full-time               False                    Georgia
# 785648         Full-time               False  California, United States
# 785682         Full-time               False                    Germany
# 785692         Full-time               False    Illinois, United States
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28      2023-08-01 13:37:57                  False                 False
# 77      2023-06-26 14:22:54                  False                 False
# 92      2023-02-21 13:29:59                  False                  True
# 100     2023-07-31 13:01:18                  False                  True
# 109     2023-10-12 13:02:19                  False                  True
# ...                     ...                    ...                   ...
# 785624  2023-08-31 06:02:16                  False                  True
# 785641  2023-01-04 16:36:07                   True                 False
# 785648  2023-04-12 06:02:51                  False                  True
# 785682  2023-03-04 06:16:08                  False                 False
# 785692  2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0              NaN
# 77              Sudan        year         140000.0              NaN
# 92      United States        year         120000.0              NaN
# 100     United States        year         228222.0              NaN
# 109     United States        year          89000.0              NaN
# ...               ...         ...              ...              ...
# 785624  United States        year         139216.0              NaN
# 785641  United States        year         150000.0              NaN
# 785648  United States        year         221875.0              NaN
# 785682        Germany        year         157500.0              NaN
# 785692  United States        year         157500.0              NaN
#
#                            company_name  \
# 28                             Netskope
# 77                           Intelletec
# 92                         Apex Systems
# 100                              TikTok
# 109     Get It Recruit - Transportation
# ...                                 ...
# 785624                      Bosch Group
# 785641            Engage Partners, Inc.
# 785648                           84.51°
# 785682                      Bosch Group
# 785692                           Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 109                 ['python', 'r', 'alteryx', 'tableau']
# ...                                                   ...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785641                                               None
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                   ...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641                                               None
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [22003 rows x 17 columns]

# %%
df[df.salary_year_avg.notnull()]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# 28      San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                                Arlington, VA     via LinkedIn
# 92                                     Anywhere     via LinkedIn
# 100                           Mountain View, CA     via LinkedIn
# 109                                    Anywhere       via Get.It
# ...                                         ...              ...
# 785624                          Mt Prospect, IL  via Ai-Jobs.net
# 785641                             New York, NY         via Dice
# 785648                        Pleasant Hill, CA  via Ai-Jobs.net
# 785682                      Reutlingen, Germany  via Ai-Jobs.net
# 785692                               Dayton, OH  via Ai-Jobs.net
#
#        job_schedule_type  job_work_from_home            search_location  \
# 28             Full-time               False                 Costa Rica
# 77             Full-time               False                      Sudan
# 92             Full-time                True    Illinois, United States
# 100            Full-time               False  California, United States
# 109            Full-time                True    Illinois, United States
# ...                  ...                 ...                        ...
# 785624         Full-time               False    Illinois, United States
# 785641         Full-time               False                    Georgia
# 785648         Full-time               False  California, United States
# 785682         Full-time               False                    Germany
# 785692         Full-time               False    Illinois, United States
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28      2023-08-01 13:37:57                  False                 False
# 77      2023-06-26 14:22:54                  False                 False
# 92      2023-02-21 13:29:59                  False                  True
# 100     2023-07-31 13:01:18                  False                  True
# 109     2023-10-12 13:02:19                  False                  True
# ...                     ...                    ...                   ...
# 785624  2023-08-31 06:02:16                  False                  True
# 785641  2023-01-04 16:36:07                   True                 False
# 785648  2023-04-12 06:02:51                  False                  True
# 785682  2023-03-04 06:16:08                  False                 False
# 785692  2023-04-21 06:02:31                  False                  True
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28         Costa Rica        year         109500.0              NaN
# 77              Sudan        year         140000.0              NaN
# 92      United States        year         120000.0              NaN
# 100     United States        year         228222.0              NaN
# 109     United States        year          89000.0              NaN
# ...               ...         ...              ...              ...
# 785624  United States        year         139216.0              NaN
# 785641  United States        year         150000.0              NaN
# 785648  United States        year         221875.0              NaN
# 785682        Germany        year         157500.0              NaN
# 785692  United States        year         157500.0              NaN
#
#                            company_name  \
# 28                             Netskope
# 77                           Intelletec
# 92                         Apex Systems
# 100                              TikTok
# 109     Get It Recruit - Transportation
# ...                                 ...
# 785624                      Bosch Group
# 785641            Engage Partners, Inc.
# 785648                           84.51°
# 785682                      Bosch Group
# 785692                           Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 109                 ['python', 'r', 'alteryx', 'tableau']
# ...                                                   ...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785641                                               None
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                   ...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785641                                               None
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [22003 rows x 17 columns]

# %% [markdown]
# You can apply this to multiple columns as well. Only return rows where the columns: salary_year_avg and job_skills are not null.

# %%
df[df[['salary_year_avg', 'job_skills']].notna().all(axis=1)]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# 28      San José Province, San José, Costa Rica
# 77                                Arlington, VA
# 92                                     Anywhere
# 100                           Mountain View, CA
# 109                                    Anywhere
# ...                                         ...
# 785563                            Pensacola, FL
# 785624                          Mt Prospect, IL
# 785648                        Pleasant Hill, CA
# 785682                      Reutlingen, Germany
# 785692                               Dayton, OH
#
#                                           job_via job_schedule_type  \
# 28                                via Ai-Jobs.net         Full-time
# 77                                   via LinkedIn         Full-time
# 92                                   via LinkedIn         Full-time
# 100                                  via LinkedIn         Full-time
# 109                                    via Get.It         Full-time
# ...                                           ...               ...
# 785563  via Navy Federal Credit Union - Talentify         Full-time
# 785624                            via Ai-Jobs.net         Full-time
# 785648                            via Ai-Jobs.net         Full-time
# 785682                            via Ai-Jobs.net         Full-time
# 785692                            via Ai-Jobs.net         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# 28                   False                 Costa Rica  2023-08-01 13:37:57
# 77                   False                      Sudan  2023-06-26 14:22:54
# 92                    True    Illinois, United States  2023-02-21 13:29:59
# 100                  False  California, United States  2023-07-31 13:01:18
# 109                   True    Illinois, United States  2023-10-12 13:02:19
# ...                    ...                        ...                  ...
# 785563               False     Florida, United States  2023-01-11 06:22:10
# 785624               False    Illinois, United States  2023-08-31 06:02:16
# 785648               False  California, United States  2023-04-12 06:02:51
# 785682               False                    Germany  2023-03-04 06:16:08
# 785692               False    Illinois, United States  2023-04-21 06:02:31
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 28                      False                 False     Costa Rica
# 77                      False                 False          Sudan
# 92                      False                  True  United States
# 100                     False                  True  United States
# 109                     False                  True  United States
# ...                       ...                   ...            ...
# 785563                  False                 False  United States
# 785624                  False                  True  United States
# 785648                  False                  True  United States
# 785682                  False                 False        Germany
# 785692                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 28            year         109500.0              NaN
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# 100           year         228222.0              NaN
# 109           year          89000.0              NaN
# ...            ...              ...              ...
# 785563        year         136400.0              NaN
# 785624        year         139216.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
#                            company_name  \
# 28                             Netskope
# 77                           Intelletec
# 92                         Apex Systems
# 100                              TikTok
# 109     Get It Recruit - Transportation
# ...                                 ...
# 785563        Navy Federal Credit Union
# 785624                      Bosch Group
# 785648                           84.51°
# 785682                      Bosch Group
# 785692                           Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 109                 ['python', 'r', 'alteryx', 'tableau']
# ...                                                   ...
# 785563  ['r', 'python', 'matplotlib', 'ggplot2', 'spar...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                   ...
# 785563  {'analyst_tools': ['word', 'power bi', 'tablea...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [20170 rows x 17 columns]

# %%
df[df['salary_year_avg'].notna() & df['job_skills'].notna()]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location  \
# 28      San José Province, San José, Costa Rica
# 77                                Arlington, VA
# 92                                     Anywhere
# 100                           Mountain View, CA
# 109                                    Anywhere
# ...                                         ...
# 785563                            Pensacola, FL
# 785624                          Mt Prospect, IL
# 785648                        Pleasant Hill, CA
# 785682                      Reutlingen, Germany
# 785692                               Dayton, OH
#
#                                           job_via job_schedule_type  \
# 28                                via Ai-Jobs.net         Full-time
# 77                                   via LinkedIn         Full-time
# 92                                   via LinkedIn         Full-time
# 100                                  via LinkedIn         Full-time
# 109                                    via Get.It         Full-time
# ...                                           ...               ...
# 785563  via Navy Federal Credit Union - Talentify         Full-time
# 785624                            via Ai-Jobs.net         Full-time
# 785648                            via Ai-Jobs.net         Full-time
# 785682                            via Ai-Jobs.net         Full-time
# 785692                            via Ai-Jobs.net         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# 28                   False                 Costa Rica  2023-08-01 13:37:57
# 77                   False                      Sudan  2023-06-26 14:22:54
# 92                    True    Illinois, United States  2023-02-21 13:29:59
# 100                  False  California, United States  2023-07-31 13:01:18
# 109                   True    Illinois, United States  2023-10-12 13:02:19
# ...                    ...                        ...                  ...
# 785563               False     Florida, United States  2023-01-11 06:22:10
# 785624               False    Illinois, United States  2023-08-31 06:02:16
# 785648               False  California, United States  2023-04-12 06:02:51
# 785682               False                    Germany  2023-03-04 06:16:08
# 785692               False    Illinois, United States  2023-04-21 06:02:31
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 28                      False                 False     Costa Rica
# 77                      False                 False          Sudan
# 92                      False                  True  United States
# 100                     False                  True  United States
# 109                     False                  True  United States
# ...                       ...                   ...            ...
# 785563                  False                 False  United States
# 785624                  False                  True  United States
# 785648                  False                  True  United States
# 785682                  False                 False        Germany
# 785692                  False                  True  United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 28            year         109500.0              NaN
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# 100           year         228222.0              NaN
# 109           year          89000.0              NaN
# ...            ...              ...              ...
# 785563        year         136400.0              NaN
# 785624        year         139216.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
#                            company_name  \
# 28                             Netskope
# 77                           Intelletec
# 92                         Apex Systems
# 100                              TikTok
# 109     Get It Recruit - Transportation
# ...                                 ...
# 785563        Navy Federal Credit Union
# 785624                      Bosch Group
# 785648                           84.51°
# 785682                      Bosch Group
# 785692                           Tenet3
#
#                                                job_skills  \
# 28                                      ['gdpr', 'excel']
# 77      ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                      ['sql', 'python']
# 100                     ['sql', 'r', 'python', 'express']
# 109                 ['python', 'r', 'alteryx', 'tableau']
# ...                                                   ...
# 785563  ['r', 'python', 'matplotlib', 'ggplot2', 'spar...
# 785624  ['go', 'python', 'r', 'sql', 'oracle', 'window...
# 785648          ['python', 'azure', 'snowflake', 'spark']
# 785682  ['python', 'hadoop', 'spark', 'airflow', 'kube...
# 785692                          ['python', 'matlab', 'r']
#
#                                           job_type_skills
# 28      {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77      {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                     {'programming': ['sql', 'python']}
# 100     {'programming': ['sql', 'r', 'python'], 'webfr...
# 109     {'analyst_tools': ['alteryx', 'tableau'], 'pro...
# ...                                                   ...
# 785563  {'analyst_tools': ['word', 'power bi', 'tablea...
# 785624  {'analyst_tools': ['alteryx', 'power bi', 'tab...
# 785648  {'cloud': ['azure', 'snowflake'], 'libraries':...
# 785682  {'libraries': ['hadoop', 'spark', 'airflow'], ...
# 785692         {'programming': ['python', 'matlab', 'r']}
#
# [20170 rows x 17 columns]

# %%
df.notna()
# Out:
#         job_title_short  job_title  job_location  job_via  job_schedule_type  \
# 0                  True       True          True     True               True
# 1                  True       True          True     True               True
# 2                  True       True          True     True               True
# 3                  True       True          True     True               True
# 4                  True       True          True     True               True
# ...                 ...        ...           ...      ...                ...
# 785736             True       True          True     True               True
# 785737             True       True          True     True               True
# 785738             True       True          True     True               True
# 785739             True       True          True     True               True
# 785740             True       True          True     True               True
#
#         job_work_from_home  search_location  job_posted_date  \
# 0                     True             True             True
# 1                     True             True             True
# 2                     True             True             True
# 3                     True             True             True
# 4                     True             True             True
# ...                    ...              ...              ...
# 785736                True             True             True
# 785737                True             True             True
# 785738                True             True             True
# 785739                True             True             True
# 785740                True             True             True
#
#         job_no_degree_mention  job_health_insurance  job_country  salary_rate  \
# 0                        True                  True         True        False
# 1                        True                  True         True        False
# 2                        True                  True         True        False
# 3                        True                  True         True        False
# 4                        True                  True         True        False
# ...                       ...                   ...          ...          ...
# 785736                   True                  True         True        False
# 785737                   True                  True         True        False
# 785738                   True                  True         True        False
# 785739                   True                  True         True        False
# 785740                   True                  True         True        False
#
#         salary_year_avg  salary_hour_avg  company_name  job_skills  \
# 0                 False            False          True       False
# 1                 False            False          True        True
# 2                 False            False          True        True
# 3                 False            False          True        True
# 4                 False            False          True        True
# ...                 ...              ...           ...         ...
# 785736            False            False          True        True
# 785737            False            False          True        True
# 785738            False            False          True        True
# 785739            False            False          True        True
# 785740            False            False          True        True
#
#         job_type_skills
# 0                 False
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# ...                 ...
# 785736             True
# 785737             True
# 785738             True
# 785739             True
# 785740             True
#
# [785741 rows x 17 columns]

# %% [markdown]
# #Pandas Cleaning

# %% [markdown]
# ### Datetime
#
# #### Notes
#
# * `pd.to_datetime()`: Convert argument to datetime.
#
# #### Example
#
# In our DataFrame the `job_posted_date` is actually a string not a datetime format. First let's convert it to datetime format.
#
# We'll also use `info()` to check if the data type changed from a string to a `datetime` format.

# %%
type(df['job_posted_date'][0])
# Out:
# str

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %% [markdown]
# ### Date
#
# #### Notes
#
# * `dt`: accessor that provides a way to access specialized methods and properties we use to work with datatime data within a pandas series.
# * `date`: extract the date component from the datetime object in the series.
# * Use together `dt.date` on our series.
#
# #### Example
#
# Now let's turn it from a datetime to a date using `dt.date`.

# %%
df['job_posted_date'] = df['job_posted_date'].dt.date
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), float64(2), object(12)
# memory usage: 86.2+ MB

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location job_posted_date  \
# 0               False  Texas, United States      2023-06-16
# 1               False                Mexico      2023-01-14
# 2               False               Germany      2023-10-10
# 3               False  Texas, United States      2023-07-04
# 4               False                 Sudan      2023-08-07
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %% [markdown]
# ## Sorting Values
#
# ### Notes
#
# * `sort_values()` sorts a DataFrame or a specific column in ascending or descending order based on one or more columns.
# * Typically this is used to sort by a specific column/s.
# * Parameters:
#     * `by` - column name or list of column names to sort by
#     * `ascending` - boolean or list of booleans, default `True`, to sort by descending you would use `False`
#     * `inplace` - whether to modify the DataFrame in place or return a new one
#
# ### Example
#
# Let's sort our DataFrame by the `job_posted_date` in descending order (from most recent date to least).

# %%
df.sort_values(by='job_posted_date', ascending=False, inplace=True)
df.head()
# Out:
#              job_title_short  \
# 287457  Senior Data Engineer
# 646083        Data Scientist
# 114666  Senior Data Engineer
# 696752         Data Engineer
# 83884      Software Engineer
#
#                                                 job_title  \
# 287457                               Senior Data Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# 114666                      Senior Data Engineer (Python)
# 696752                            Senior Data Engineer II
# 83884                         SAP B1 Applications Analyst
#
#                    job_location             job_via        job_schedule_type  \
# 287457   Randburg, South Africa  via CareerJunction                Full-time
# 646083  Nieuwegein, Netherlands    via Utrecht.work                Full-time
# 114666        Wichita Falls, TX        via LinkedIn  Full-time and Part-time
# 696752               Orange, CA           via BeBee                Full-time
# 83884                   Germany           via BeBee                Full-time
#
#         job_work_from_home search_location job_posted_date  \
# 287457               False    South Africa      2023-12-31
# 646083               False     Netherlands      2023-12-31
# 114666               False         Georgia      2023-12-31
# 696752               False           Sudan      2023-12-31
# 83884                False         Germany      2023-12-31
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 287457                  False                 False   South Africa
# 646083                  False                 False    Netherlands
# 114666                  False                  True  United States
# 696752                  False                  True          Sudan
# 83884                    True                 False        Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 287457        None              NaN              NaN
# 646083        None              NaN              NaN
# 114666        None              NaN              NaN
# 696752        None              NaN              NaN
# 83884         None              NaN              NaN
#
#                           company_name  \
# 287457  DCV Sabenza IT and Recruitment
# 646083          Nationale Vacaturebank
# 114666                    ClickJobs.io
# 696752                    MobilityWare
# 83884              Systems Accountants
#
#                                                job_skills  \
# 287457  ['sql', 'python', 'databricks', 'azure', 'hado...
# 646083                                               None
# 114666  ['python', 'java', 'scala', 'nosql', 'sql', 'm...
# 696752  ['python', 'java', 'c#', 'sql', 'aws', 'snowfl...
# 83884                           ['sql', 'crystal', 'sap']
#
#                                           job_type_skills
# 287457  {'analyst_tools': ['ssrs', 'power bi', 'tablea...
# 646083                                               None
# 114666  {'cloud': ['redshift', 'snowflake', 'aws', 'az...
# 696752  {'cloud': ['aws', 'snowflake', 'gcp'], 'librar...
# 83884   {'analyst_tools': ['sap'], 'programming': ['sq...

# %% [markdown]
# ## Adding a Column
#
# ### Notes
#
# - If you want to create a column you'll need to use the `df['column_name']` syntax.
#
# ### Example
#
# Here we are creating a new column called 'Is Data Analyst' and saying if the column `job_title_short` is equal to 'Data Analyst' then then return 1 if not, return 0. It does this by using `astype(int)`.

# %%
df.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills', 'job_type_skills', 'Is Data Analyst'],
#       dtype='object')

# %%
df.job_schedule_type
# Out:
# 287457                  Full-time
# 646083                  Full-time
# 114666    Full-time and Part-time
# 696752                  Full-time
# 83884                   Full-time
#                    ...
# 542527                  Full-time
# 137492                  Full-time
# 778984                  Full-time
# 707242                  Full-time
# 347766                  Full-time
# Name: job_schedule_type, Length: 785741, dtype: object

# %%
df['Full_time_job'] = (df.job_schedule_type == 'Full-time').astype(int)

# %%
df['Full_time_job']
# Out:
# 287457    1
# 646083    1
# 114666    0
# 696752    1
# 83884     1
#          ..
# 542527    1
# 137492    1
# 778984    1
# 707242    1
# 347766    1
# Name: Full_time_job, Length: 785741, dtype: int64

# %%
df[df['Full_time_job'] > 0].head()
# Out:
#              job_title_short  \
# 287457  Senior Data Engineer
# 646083        Data Scientist
# 696752         Data Engineer
# 83884      Software Engineer
# 507726         Data Engineer
#
#                                                 job_title  \
# 287457                               Senior Data Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# 696752                            Senior Data Engineer II
# 83884                         SAP B1 Applications Analyst
# 507726                                      Data Engineer
#
#                    job_location             job_via job_schedule_type  \
# 287457   Randburg, South Africa  via CareerJunction         Full-time
# 646083  Nieuwegein, Netherlands    via Utrecht.work         Full-time
# 696752               Orange, CA           via BeBee         Full-time
# 83884                   Germany           via BeBee         Full-time
# 507726                   France           via BeBee         Full-time
#
#         job_work_from_home search_location job_posted_date  \
# 287457               False    South Africa      2023-12-31
# 646083               False     Netherlands      2023-12-31
# 696752               False           Sudan      2023-12-31
# 83884                False         Germany      2023-12-31
# 507726               False          France      2023-12-31
#
#         job_no_degree_mention  job_health_insurance   job_country salary_rate  \
# 287457                  False                 False  South Africa        None
# 646083                  False                 False   Netherlands        None
# 696752                  False                  True         Sudan        None
# 83884                    True                 False       Germany        None
# 507726                   True                 False        France        None
#
#         salary_year_avg  salary_hour_avg                    company_name  \
# 287457              NaN              NaN  DCV Sabenza IT and Recruitment
# 646083              NaN              NaN          Nationale Vacaturebank
# 696752              NaN              NaN                    MobilityWare
# 83884               NaN              NaN             Systems Accountants
# 507726              NaN              NaN                     Groupe BPCE
#
#                                                job_skills  \
# 287457  ['sql', 'python', 'databricks', 'azure', 'hado...
# 646083                                               None
# 696752  ['python', 'java', 'c#', 'sql', 'aws', 'snowfl...
# 83884                           ['sql', 'crystal', 'sap']
# 507726          ['scala', 'c#', 'sql', 'hadoop', 'spark']
#
#                                           job_type_skills  Is Data Analyst  \
# 287457  {'analyst_tools': ['ssrs', 'power bi', 'tablea...                0
# 646083                                               None                0
# 696752  {'cloud': ['aws', 'snowflake', 'gcp'], 'librar...                0
# 83884   {'analyst_tools': ['sap'], 'programming': ['sq...                0
# 507726  {'libraries': ['hadoop', 'spark'], 'programmin...                0
#
#         Full_time_job
# 287457              1
# 646083              1
# 696752              1
# 83884               1
# 507726              1

# %% [markdown]
# ## Dropping Data
#
# ### Notes
#
# * Use `drop()` if you want to drop (delete) either a column or row in your database.
# * The syntax is:
#     * Drop column: `df.drop('column_name, axis = 1)`
#     * Drop row: `df.drop(index_name, axis = 0)`
# * If you wanted to drop multiple rows you would have the syntax:
#     * Drop multiple columns: `df.drop(['column_name1', 'column_name2'], axis=1)`
#     * Drop multiple rows: `df.drop([index_name1, index_name2], axis=0)`
#
# ### Examples
#
# Let's drop the column `'salary_hour_avg'`, this will have an axis of 1 (since we're dropping a column).

# %%
df.drop('salary_hour_avg', axis = 1)
# Out:
#              job_title_short  \
# 287457  Senior Data Engineer
# 646083        Data Scientist
# 114666  Senior Data Engineer
# 696752         Data Engineer
# 83884      Software Engineer
# ...                      ...
# 542527        Data Scientist
# 137492         Data Engineer
# 778984        Cloud Engineer
# 707242     Software Engineer
# 347766         Data Engineer
#
#                                                 job_title  \
# 287457                               Senior Data Engineer
# 646083  DATA SCIENTIST regio Utrecht – PHARMO Institut...
# 114666                      Senior Data Engineer (Python)
# 696752                            Senior Data Engineer II
# 83884                         SAP B1 Applications Analyst
# ...                                                   ...
# 542527                            Data Science Consultant
# 137492                  Data Engineer - Customer Insights
# 778984                   Configuration Management Analyst
# 707242                                  Software Engineer
# 347766                    Manager, Data Engineering, SMAI
#
#                              job_location                           job_via  \
# 287457             Randburg, South Africa                via CareerJunction
# 646083            Nieuwegein, Netherlands                  via Utrecht.work
# 114666                  Wichita Falls, TX                      via LinkedIn
# 696752                         Orange, CA                         via BeBee
# 83884                             Germany                         via BeBee
# ...                                   ...                               ...
# 542527  Taguig, Metro Manila, Philippines                   via Trabajo.org
# 137492             Amsterdam, Netherlands                         via Melga
# 778984                    Dublin, Ireland                   via Trabajo.org
# 707242                            Finland                   via Trabajo.org
# 347766        Bengaluru, Karnataka, India  via Careers At Micron Technology
#
#               job_schedule_type  job_work_from_home search_location  \
# 287457                Full-time               False    South Africa
# 646083                Full-time               False     Netherlands
# 114666  Full-time and Part-time               False         Georgia
# 696752                Full-time               False           Sudan
# 83884                 Full-time               False         Germany
# ...                         ...                 ...             ...
# 542527                Full-time               False     Philippines
# 137492                Full-time               False     Netherlands
# 778984                Full-time               False         Ireland
# 707242                Full-time               False         Finland
# 347766                Full-time               False           India
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 287457      2023-12-31                  False                 False
# 646083      2023-12-31                  False                 False
# 114666      2023-12-31                  False                  True
# 696752      2023-12-31                  False                  True
# 83884       2023-12-31                   True                 False
# ...                ...                    ...                   ...
# 542527      2023-01-01                  False                 False
# 137492      2023-01-01                  False                 False
# 778984      2023-01-01                   True                 False
# 707242      2023-01-01                  False                 False
# 347766      2023-01-01                  False                 False
#
#           job_country salary_rate  salary_year_avg  \
# 287457   South Africa        None              NaN
# 646083    Netherlands        None              NaN
# 114666  United States        None              NaN
# 696752          Sudan        None              NaN
# 83884         Germany        None              NaN
# ...               ...         ...              ...
# 542527    Philippines        None              NaN
# 137492    Netherlands        None              NaN
# 778984        Ireland        None              NaN
# 707242        Finland        None              NaN
# 347766          India        None              NaN
#
#                           company_name  \
# 287457  DCV Sabenza IT and Recruitment
# 646083          Nationale Vacaturebank
# 114666                    ClickJobs.io
# 696752                    MobilityWare
# 83884              Systems Accountants
# ...                                ...
# 542527                             AIA
# 137492                     Booking.com
# 778984               Vantage Resources
# 707242                            Uber
# 347766               Micron Technology
#
#                                                job_skills  \
# 287457  ['sql', 'python', 'databricks', 'azure', 'hado...
# 646083                                               None
# 114666  ['python', 'java', 'scala', 'nosql', 'sql', 'm...
# 696752  ['python', 'java', 'c#', 'sql', 'aws', 'snowfl...
# 83884                           ['sql', 'crystal', 'sap']
# ...                                                   ...
# 542527                                               None
# 137492  ['java', 'scala', 'python', 'perl', 'sql', 'my...
# 778984                                               None
# 707242  ['c++', 'nosql', 'python', 'java', 'go', 'kafka']
# 347766           ['python', 'snowflake', 'gcp', 'hadoop']
#
#                                           job_type_skills  Is Data Analyst  \
# 287457  {'analyst_tools': ['ssrs', 'power bi', 'tablea...                0
# 646083                                               None                0
# 114666  {'cloud': ['redshift', 'snowflake', 'aws', 'az...                0
# 696752  {'cloud': ['aws', 'snowflake', 'gcp'], 'librar...                0
# 83884   {'analyst_tools': ['sap'], 'programming': ['sq...                0
# ...                                                   ...              ...
# 542527                                               None                0
# 137492  {'databases': ['mysql', 'cassandra'], 'librari...                0
# 778984                                               None                0
# 707242  {'libraries': ['kafka'], 'programming': ['c++'...                0
# 347766  {'cloud': ['snowflake', 'gcp'], 'libraries': [...                0
#
#         Full_time_job
# 287457              1
# 646083              1
# 114666              0
# 696752              1
# 83884               1
# ...               ...
# 542527              1
# 137492              1
# 778984              1
# 707242              1
# 347766              1
#
# [785741 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 287457 to 347766
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
#  17  Is Data Analyst        785741 non-null  int64
#  18  Full_time_job          785741 non-null  int64
# dtypes: bool(3), float64(2), int64(2), object(12)
# memory usage: 104.2+ MB

# %%
df.drop('salary_hour_avg', axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 287457 to 347766
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
#  14  job_skills             668704 non-null  object
#  15  job_type_skills        668704 non-null  object
#  16  Is Data Analyst        785741 non-null  int64
#  17  Full_time_job          785741 non-null  int64
# dtypes: bool(3), float64(1), int64(2), object(12)
# memory usage: 98.2+ MB

# %% [markdown]
# ## Remove NA
#
# ### Notes
#
# * To remove rows that contain empty cells use `dropna()`.
# * By default `dropna()` will return a *new* DataFrame, and won't change the original.
#
# ### Example
#
# Let's cleanup our `salary_year_avg` column by removing the `NaN` values in this column.

# %%
df.salary_year_avg.head()
# Out:
# 287457   NaN
# 646083   NaN
# 114666   NaN
# 696752   NaN
# 83884    NaN
# Name: salary_year_avg, dtype: float64

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df = df[df['salary_year_avg'].notna()]

# %%
df.salary_year_avg.head()
# Out:
# 574802     95150.0
# 120858    144000.0
# 122037    137500.0
# 3448      140000.0
# 581356    135000.0
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# # Pandas Analysis

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Describe()
#
# #### Notes
#
# For a basic overview we'll be using `describe()`.
# * It gets the following (for columns with numeric data):
#   * count
#   * mean
#   * std
#   * min
#   * max
# * Great for getting a quick overview of the basic stats for the table.
# * It automatically skips NaN values.
#
# #### Example
#
# Use `describe()` on our DataFrame.

# %%
df.describe()
# Out:
#        salary_year_avg  Is Data Analyst  Full_time_job
# count     22003.000000     22003.000000   22003.000000
# mean     123286.274072         0.247739       0.955233
# std       48312.449482         0.431709       0.206796
# min       15000.000000         0.000000       0.000000
# 25%       90000.000000         0.000000       1.000000
# 50%      115000.000000         0.000000       1.000000
# 75%      150000.000000         0.000000       1.000000
# max      960000.000000         1.000000       1.000000

# %%
df['salary_year_avg'].describe() #for individual columns
# Out:
# count     22003.000000
# mean     123286.274072
# std       48312.449482
# min       15000.000000
# 25%       90000.000000
# 50%      115000.000000
# 75%      150000.000000
# max      960000.000000
# Name: salary_year_avg, dtype: float64

# %% [markdown]
# ### Common Data Analysis Methods
#
# #### Notes
#
# But there are other methods like:
# * `df.sum()` - Sum of values
# * `df.cumsum()` - Cummulative sum of values
# * `df.min()`/`df.max()` - Minimum/maximum values
# * `df.idxmin()`/`df.idxmax()` - Indexes of minimum/Maximum value
# * `df.mean()` - Mean of values
# * `df.median()` - Median of values
# * `df.mode()` - Mode of the values
# * `series.value_counts()` - Counts of unique values for a Series (aka a column)
#     * Typically used for counting *unique occurrences* within a single column.
#     * It's not applicable to an entire DataFrame without specifying a column.
# * Depending on the method, you can apply it directly to a DataFrame or a Series.
#
# #### Examples
#
# Let's get the count of the values in each column within the entire DataFrame.

# %%
df['salary_year_avg'].mode()
# Out:
# 0    90000.0
# Name: salary_year_avg, dtype: float64

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df['salary_year_avg'].sum()
# Out:
# np.float64(2712667888.4023438)

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
df['salary_year_avg'].max()
# Out:
# 960000.0

# %%
df['salary_year_avg'].idxmax()
# Out:
# np.int64(554784)

# %%
df
# Out:
#              job_title_short                                     job_title  \
# 574802   Senior Data Analyst                      Senior Reporting Analyst
# 120858          Data Analyst                 Machine Learning Data Analyst
# 122037        Data Scientist                     Data Scientist, Principal
# 3448    Senior Data Engineer  Senior Python Developer for Data Engineering
# 581356  Senior Data Engineer                          Senior Data Engineer
# ...                      ...                                           ...
# 47131           Data Analyst                               HR Data Analyst
# 69156         Data Scientist                          Staff Data Scientist
# 705374        Data Scientist                          Data Science Manager
# 449502         Data Engineer                                 Data Engineer
# 728461          Data Analyst                                  Data Analyst
#
#            job_location       job_via job_schedule_type  job_work_from_home  \
# 574802    Iowa City, IA   via Ladders         Full-time               False
# 120858         Anywhere    via Get.It         Full-time                True
# 122037  Mid Florida, FL   via Ladders         Full-time               False
# 3448       New York, NY  via LinkedIn         Full-time               False
# 581356         Anywhere    via Get.It         Full-time                True
# ...                 ...           ...               ...                 ...
# 47131    Washington, DC    via Indeed         Full-time               False
# 69156          Anywhere    via Indeed         Full-time                True
# 705374     Carnegie, PA    via Indeed         Full-time               False
# 449502     Dearborn, MI    via Indeed        Contractor               False
# 728461       California  via LinkedIn        Contractor               False
#
#                   search_location job_posted_date  job_no_degree_mention  \
# 574802    Illinois, United States      2023-12-31                  False
# 120858  California, United States      2023-12-31                  False
# 122037     Florida, United States      2023-12-31                  False
# 3448                      Georgia      2023-12-31                   True
# 581356     Florida, United States      2023-12-31                  False
# ...                           ...             ...                    ...
# 47131     New York, United States      2023-01-01                   True
# 69156   California, United States      2023-01-01                  False
# 705374                    Georgia      2023-01-01                  False
# 449502    Illinois, United States      2023-01-01                  False
# 728461  California, United States      2023-01-01                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 574802                  True  United States        year          95150.0
# 120858                  True  United States        year         144000.0
# 122037                  True  United States        year         137500.0
# 3448                   False  United States        year         140000.0
# 581356                  True  United States        year         135000.0
# ...                      ...            ...         ...              ...
# 47131                   True  United States        year          77500.0
# 69156                   True  United States        year         202500.0
# 705374                  True  United States        year         133500.0
# 449502                 False  United States        year         165000.0
# 728461                 False  United States        year          92500.0
#
#                                    company_name  \
# 574802                               CVS Health
# 120858  Get It Recruit - Information Technology
# 122037                          Blackbaud, Inc.
# 3448                                     Luxoft
# 581356  Get It Recruit - Information Technology
# ...                                         ...
# 47131                               CyberCoders
# 69156                               CyberCoders
# 705374                                   VISIMO
# 449502                           Stefanini, Inc
# 728461                              Robert Half
#
#                                                job_skills  \
# 574802  ['sql', 't-sql', 'sql server', 'ssrs', 'tableau']
# 120858  ['sql', 'python', 'matplotlib', 'tableau', 'po...
# 122037             ['python', 'r', 'databricks', 'azure']
# 3448                                    ['python', 'sql']
# 581356  ['sql', 'python', 'snowflake', 'databricks', '...
# ...                                                   ...
# 47131                                      ['sharepoint']
# 69156   ['python', 'java', 'scala', 'sql', 'aws', 'had...
# 705374  ['python', 'numpy', 'pandas', 'scikit-learn', ...
# 449502  ['sql', 'python', 'gcp', 'bigquery', 'spring',...
# 728461                                 ['sql', 'tableau']
#
#                                           job_type_skills  Is Data Analyst  \
# 574802  {'analyst_tools': ['ssrs', 'tableau'], 'databa...                0
# 120858  {'analyst_tools': ['tableau', 'power bi'], 'li...                1
# 122037  {'cloud': ['databricks', 'azure'], 'programmin...                0
# 3448                   {'programming': ['python', 'sql']}                0
# 581356  {'cloud': ['snowflake', 'databricks', 'azure',...                0
# ...                                                   ...              ...
# 47131                   {'analyst_tools': ['sharepoint']}                1
# 69156   {'cloud': ['aws'], 'libraries': ['hadoop', 'sp...                0
# 705374  {'libraries': ['numpy', 'pandas', 'scikit-lear...                0
# 449502  {'cloud': ['gcp', 'bigquery'], 'libraries': ['...                0
# 728461  {'analyst_tools': ['tableau'], 'programming': ...                1
#
#         Full_time_job
# 574802              1
# 120858              1
# 122037              1
# 3448                1
# 581356              1
# ...               ...
# 47131               1
# 69156               1
# 705374              1
# 449502              0
# 728461              0
#
# [22003 rows x 18 columns]

# %% [markdown]
# ### Groupby()
#
# #### Notes
#
# * Use `groupby` to group your DataFrame by the unique values in a specific column.
# * Lets you perform aggregation (e.g. mean, sum) on the grouped data.
# * Aggregations you can perform:
#   * `mean()`: Computes the mean of the groups
#   * `sum()`: Calculates the sum of the group values
#   * `median()`: Finds the median of each group
#   * `min()` and `max()`: Determine the minimum and maximum values within each group
#   * Counts:
#     * `count()`: Counts the number of non-NA/null entries in each group
#     * `size()`: Returns the size of each group (including NA/null values)
#   * `std()` and `var()`: Calculate the standard deviation and variance of groups
#   * `first()` and `last()`: Get the first and last row of each group
#   * `unique()`: Counts the number of unique non-NA/null values in each group
#
# #### Examples
#
# If we want to find the average yearly salary by `job_title_short`.

# %%
df.groupby('job_title_short')['salary_year_avg'].mean()
# Out:
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_country')['salary_year_avg'].mean()
# Out:
# job_country
# Albania        79472.500000
# Algeria        44550.000000
# Argentina     105212.343750
# Armenia        78757.000000
# Australia     118987.574324
#                   ...
# Uruguay        69333.333333
# Uzbekistan     30750.000000
# Vietnam        90927.236364
# Zambia         90670.000000
# Zimbabwe       67056.666667
# Name: salary_year_avg, Length: 108, dtype: float64

# %% [markdown]
# ### Agg()
#
# #### Notes
#
# * `agg()` lets you apply multiple functions at once.
# * You can pass a list of functions to `agg()` to apply them all to the grouped data, or a dictionary to apply specific functions to specific columns.
#
#
# #### Example
#
# For each job title (`job_title_short`) let's get the minimum and maximum values for the salary.

# %%
df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'max'])
# Out:
#                                min       max
# job_title_short
# Business Analyst           16500.0  387460.0
# Cloud Engineer             42000.0  280000.0
# Data Analyst               25000.0  650000.0
# Data Engineer              15000.0  525000.0
# Data Scientist             27000.0  960000.0
# Machine Learning Engineer  30000.0  325000.0
# Senior Data Analyst        30000.0  425000.0
# Senior Data Engineer       35000.0  425000.0
# Senior Data Scientist      45000.0  890000.0
# Software Engineer          28000.0  375000.0
